# %%
# !pip show requests

# %%
import  requests
from bs4 import beautifulsoup4
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_205772/1018385225.py in <module>
#       1 import  requests
# ----> 2 from bs4 import beautifulsoup4
#       3
#       4
#
# ImportError: cannot import name 'beautifulsoup4' from 'bs4' (C:\Users\User\anaconda3\lib\site-packages\bs4\__init__.py)

# %%
import requests
from bs4 import BeautifulSoup4
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_205772/2204555661.py in <module>
#       1 import requests
# ----> 2 from bs4 import BeautifulSoup4
#
# ImportError: cannot import name 'BeautifulSoup4' from 'bs4' (C:\Users\User\anaconda3\lib\site-packages\bs4\__init__.py)

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101'
req_header_dic ={
    'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36'
}
res = requests.get(url, headers=req_header_dic)
print(res.status_code, res.ok)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_205772/3343841901.py in <module>
#       3     'user-agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36'
#       4 }
# ----> 5 res = requests.get(url, headers=req_header_dic)
#       6 print(res.status_code, res.ok)
#
# ~\anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ...

# %%
url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101'
req_header_dic ={
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36'
}
res = requests.get(url, headers=req_header_dic)
print(res.status_code, res.ok)
print('응답헤더 : ', res.headers)
print('요청헤더 : ', res.request.headers)
# Out:
# 200 True
# 응답헤더 :  {'date': 'Thu, 27 Jan 2022 05:31:52 GMT', 'cache-control': 'no-cache', 'expires': 'Thu, 01 Jan 1970 00:00:00 GMT', 'set-cookie': 'JSESSIONID=1677B7DCEFC7FC91A6CCEC8B376B9503; Path=/main; HttpOnly', 'content-language': 'ko-KR', 'vary': 'Accept-Encoding', 'content-encoding': 'gzip', 'transfer-encoding': 'chunked', 'content-type': 'text/html;charset=EUC-KR', 'referrer-policy': 'unsafe-url', 'server': 'nfront'}
# 요청헤더 :  {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.99 Safari/537.36', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
if res.ok:
    html = res.text
    soup = BeautifulSoup(html, 'html.parser')
    atag_list = soup.select("a[href*='read.naver']")
    print(len(atag_list))

    for atag in atag_list:
        print(atag)
# Out:
# 240
# <a class="cluster_thumb_link nclicks(cls_eco.clsart)" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=119&amp;aid=0002571089">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/119/2022/01/27/2571089.jpg?type=nf132_90" width="132"/>
# </a>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=119&amp;aid=0002571089">한은 “빅테크 반독점 규체 체계 개편해야”</a>
# <a class="cluster_text_headline nclicks(cls_eco.clsart)" href="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=shm&amp;sid1=101&amp;oid=001&amp;aid=0012945223">"빅테크 독과점, 현 체계로는 규제 어렵다…개편해야"</a>
# ...

# %%
for atag in atag_list:
    title = atag.text.strip()
    print(title)
# Out:
# 한은 “빅테크 반독점 규체 체계 개편해야”
# "빅테크 독과점, 현 체계로는 규제 어렵다…개편해야"
# 올해 빅테크5 매출액 1조5720억 달러 전망…"반독점 규제체계 개편해야"
# 한은 "기존 가격 규제로는 빅테크 독과점 막기 어려워"
#
# 정은보, '윤석헌표' 종합검사 3년만 다시 폐지
# 금감원, 종합검사 대신 정기·수시검사체계 도입
# 금감원 수석부원장 "검사체계, 정기와 수시로 개편"
# '종합검사' 대신 금융사 특성별 '정기·수시검사' 한다
#
# 9년 만에 최대 실적 낸 삼성엔지니어링…작년 영업익 5033억
# 삼성엔지니어링, 지난해 영업익 5,033억원…9년 만에 최대 실적
# 삼성엔지니어링, 지난해 영업이익 5033억원.. 9년 만에 최대
# 삼성엔지니어링, 9년 만에 최대 실적... 영업이익 5000억원
#
# 울산 작년 수출액 743억 달러 '7년 만에 최고'
#
# 2022년 수출기상도…車·석유 ‘맑음’, 반도체·디스플레이 ‘구름’,  철강·조선 ‘비’
#
# 삼성바이오로직스, 탄소경영섹터 아너스 수상…기후변화 대응 노력 인정
#
# 한화솔루션, CDP '탄소경영 섹터 아너스' 수상
# 동영상기사
# 삼성전자 작년 매출 사상 최대…반도체도 1위 복귀
#
# 삼성전자, 지난해 매출 279.6조원… 사상 최대(상보)
#
# LG엔솔 상장 D-1, 움츠러든 대형주
#
# LG엔솔 상장 첫날 단번에 시총2위 등극…시초가는 59만원
#
# LG엔솔 코스피 상장…권영수 "100년을 위한 출발점"
#
# LG에너지솔루션, 상장 첫날 장 초반 급락세…시초가 대비 20%↓
#
# 전 세계 완판 행진 삼성 '더 프리스타일', 국내 공식 출시
#
# CES 달군 그 제품…삼성 ‘더 프리스타일’ 국내출시
#
# 공정위 “대기업 IT 일감, 내부거래 말고 외부에 개방해라”
#
# 공정위·과기정통부, IT서비스 일감개방 자율준수기준 공개
#
# 韓, 세계 최대 FTA ‘RCEP’ 2월 1일 발효
#
# ...

# %%
for idex, atag in enumerate(atag_list, 1):
    title = atag.text.strip()
    news_link = atag['href']
    print(f'{idex} = {title} {news_link}')
# Out:
# 1 =  https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=119&aid=0002571089
# 2 = 한은 “빅테크 반독점 규체 체계 개편해야” https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=119&aid=0002571089
# 3 = "빅테크 독과점, 현 체계로는 규제 어렵다…개편해야" https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=001&aid=0012945223
# 4 = 올해 빅테크5 매출액 1조5720억 달러 전망…"반독점 규제체계 개편해야" https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=277&aid=0005036921
# 5 = 한은 "기존 가격 규제로는 빅테크 독과점 막기 어려워" https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=011&aid=0004013062
# 6 =  https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=014&aid=0004779500
# 7 = 정은보, '윤석헌표' 종합검사 3년만 다시 폐지 https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=014&aid=0004779500
# 8 = 금감원, 종합검사 대신 정기·수시검사체계 도입 https://news.naver.com/main/read.naver?mode=LSD&mid=shm&sid1=101&oid=018&aid=0005135167
# ...
